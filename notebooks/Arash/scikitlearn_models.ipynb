# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
import lightgbm as lgb
from catboost import CatBoostRegressor

# %%
df_train = pd.read_csv('C:/Users/aminp/OneDrive/Dokumenter/NTNU/4år/Machinelearning/machine_learning/data/train_data/dataset_train_without_rev_features.csv')
df_train_extra = pd.read_csv("C:/Users/aminp/OneDrive/Dokumenter/NTNU/4år/Machinelearning/machine_learning/data/train_data/dataset_train_with_stores_extra.csv")
df_test = pd.read_csv('C:/Users/aminp/OneDrive/Dokumenter/NTNU/4år/Machinelearning/machine_learning/data/train_data/dataset_test_without_rev_features.csv')

# %%
data = df_train.drop(["store_id", "Unnamed: 0"], axis = 1)
data_with_extra = df_train_extra.drop(["Unnamed: 0"], axis = 1)
x_test = df_test.drop(["Unnamed: 0"], axis = 1)

# %%
x_train = data.drop(["revenue"], axis = 1)
y = data["revenue"]
# Out:
#        grunnkrets_id_population_count  district_name_population_count  \
# 0                               False                           False
# 1                                True                           False
# 2                               False                           False
# 3                               False                           False
# 4                                True                           False
# ...                               ...                             ...
# 12854                           False                           False
# 12855                           False                           False
# 12856                           False                           False
# 12857                           False                           False
# 12858                           False                           False
#
#        municipality_name_population_count  grunnkrets_name_num_kids  \
# 0                                   False                     False
# 1                                   False                      True
# 2                                   False                     False
# 3                                   False                     False
# 4                                   False                      True
# ...                                   ...                       ...
# 12854                               False                     False
# 12855                               False                     False
# 12856                               False                     False
# 12857                               False                     False
# 12858                               False                     False
#
#        grunnkrets_name_num_kids+  grunnkrets_name_num_youths  \
# 0                          False                       False
# 1                           True                        True
# 2                          False                       False
# 3                          False                       False
# 4                           True                        True
# ...                          ...                         ...
# 12854                      False                       False
# 12855                      False                       False
# 12856                      False                       False
# 12857                      False                       False
# 12858                      False                       False
#
#        grunnkrets_name_num_youthAdult  grunnkrets_name_num_adult  \
# 0                               False                      False
# 1                                True                       True
# 2                               False                      False
# 3                               False                      False
# 4                                True                       True
# ...                               ...                        ...
# 12854                           False                      False
# 12855                           False                      False
# 12856                           False                      False
# 12857                           False                      False
# 12858                           False                      False
#
#        grunnkrets_name_num_adults+  grunnkrets_name_num_pensinors  ...  \
# 0                            False                          False  ...
# 1                             True                           True  ...
# 2                            False                          False  ...
# 3                            False                          False  ...
# 4                             True                           True  ...
# ...                            ...                            ...  ...
# 12854                        False                          False  ...
# 12855                        False                          False  ...
# 12856                        False                          False  ...
# 12857                        False                          False  ...
# 12858                        False                          False  ...
#
#        distance_to_regionalt_knutepunkt  distance_to_annen_viktig_holdeplass  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
# ...                                 ...                                  ...
# 12854                             False                                False
# 12855                             False                                False
# 12856                             False                                False
# 12857                             False                                False
# 12858                             False                                False
#
#        distance_to_nasjonalt_knutepunkt  number_of_all_stop_types  \
# 0                                 False                     False
# 1                                 False                     False
# 2                                 False                     False
# 3                                 False                     False
# 4                                 False                     False
# ...                                 ...                       ...
# 12854                             False                     False
# 12855                             False                     False
# 12856                             False                     False
# 12857                             False                     False
# 12858                             False                     False
#
#        number_of_mangler_viktighetsnivå  number_of_standard_holdeplass  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
# ...                                 ...                            ...
# 12854                             False                          False
# 12855                             False                          False
# 12856                             False                          False
# 12857                             False                          False
# 12858                             False                          False
#
#        number_of_lokalt_knutepunkt  number_of_regionalt_knutepunkt  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 12854                        False                           False
# 12855                        False                           False
# 12856                        False                           False
# 12857                        False                           False
# 12858                        False                           False
#
#        number_of_annen_viktig_holdeplass  number_of_nasjonalt_knutepunkt
# 0                                  False                           False
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                           False
# ...                                  ...                             ...
# 12854                              False                           False
# 12855                              False                           False
# 12856                              False                           False
# 12857                              False                           False
# 12858                              False                           False
#
# [12859 rows x 140 columns]

# %% [markdown]
# # Desicion Tree

# %%
dt = DecisionTreeRegressor(
    criterion = 'squared_error',
    max_depth = 5,
    min_samples_split = 4,
    min_samples_leaf = 2,
    random_state=42
)

# %%
dt.fit(x_train, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-9ed62b0ef7a2> in <module>
# ----> 1 dt.fit(x_train, y)
#
# c:\Users\aminp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# c:\Users\aminp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# c:\Users\aminp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# c:\Users\aminp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# c:\Users\aminp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
